# %%
import pandas as pd
import numpy as np
data=pd.read_csv("E:\imdb_anime.csv")

# %%
data.tail()
# Out:
#                                 Title                         Genre  \
# 45712  Demon Slayer: Kimetsu no Yaiba  Animation, Action, Adventure
# 45713  Demon Slayer: Kimetsu no Yaiba  Animation, Action, Adventure
# 45714                       One Piece  Animation, Action, Adventure
# 45715                   Marmalade Boy      Animation, Comedy, Drama
# 45716                 Cinderella Nine       Animation, Drama, Sport
#
#       User Rating Number of Votes Runtime         Year  \
# 45712         7.3           3,432  24 min     (2019– )
# 45713         7.9           3,309  24 min     (2019– )
# 45714         9.4           2,743     NaN     (1999– )
# 45715         NaN             NaN  24 min  (1994–2005)
# 45716         6.0               6  24 min     (2019– )
#
#                                                  Summary  \
# 45712  Tanjiro heads to his next location southeast; ...
# 45713  Tanjiro gets separated from Zenitsu when he en...
# ...

# %%
#How many unique anime are there?
a=data.Title.unique()

# %%
len(a)
# Out:
# 9851

# %%
#there are 9851 unique animes are there

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45717 entries, 0 to 45716
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            45717 non-null  object
#  1   Genre            45717 non-null  object
#  2   User Rating      25009 non-null  object
#  3   Number of Votes  25009 non-null  object
#  4   Runtime          32549 non-null  object
#  5   Year             45591 non-null  object
#  6   Summary          23547 non-null  object
#  7   Stars            13676 non-null  object
#  8   Certificate      28694 non-null  object
#  9   Metascore        341 non-null    object
#  10  Gross            25009 non-null  object
#  11  Episode          45717 non-null  object
#  12  Episode Title    34910 non-null  object
# dtypes: object(13)
# memory usage: 4.5+ MB

# %%
a=data.fillna(method="ffill")

a=a.replace({"User Rating":{"User Rating":0.0}})
b=a.groupby("Genre")
b.ngroups
# Out:
# 201

# %%
a.replace({"User Rating":{"User Rating":0}},inplace=True)
a
# Out:
#                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 3                                  Attack on Titan
# 4                                   Jujutsu Kaisen
# ...                                            ...
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
# 45714                                    One Piece
# 45715                                Marmalade Boy
# 45716                              Cinderella Nine
#
#                               Genre User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure         8.9         187,689  24 min
# 1      Animation, Action, Adventure         7.4          28,895  99 min
# 2      Animation, Adventure, Comedy         7.1         189,108  92 min
# ...

# %%
#Which anime has the highest rating?

b=a.astype({"User Rating":np.float16})
b["User Rating"].max()
# Out:
# 9.9

# %%
b.loc[b['User Rating']==9.9]
# Out:
#                                Title                         Genre  \
# 13656                    Idaten Jump  Animation, Adventure, Comedy
# 13657                    Idaten Jump  Animation, Adventure, Comedy
# 17874                   Vinland Saga  Animation, Action, Adventure
# 17875                  Chuka ichiban     Animation, Action, Comedy
# 22753                Attack on Titan  Animation, Action, Adventure
# 34677                Hunter x Hunter  Animation, Action, Adventure
# 39614  Legend of the Galactic Heroes      Animation, Action, Drama
# 45689                Attack on Titan  Animation, Action, Adventure
# 45690        Fighting General Daimos  Animation, Action, Adventure
# 45691        Fighting General Daimos  Animation, Action, Adventure
#
#        User Rating Number of Votes Runtime         Year  \
# 13656     9.898438              11  20 min  (2005–2006)
# 13657     9.898438              11  20 min  (2005–2006)
# 17874     9.898438          13,663  24 min     (2019– )
# ...

# %%
#Idantan jump,vinland saga,chuka ichiba etc have the maximum ratings

# %%
b['User Rating'].min()
# Out:
# 0.0

# %%
#Which anime has a rating between 7.0 to 9.0?

b[b["User Rating"].between(7.0,7.9)]
# Out:
#                                              Title  \
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 7                     Puss in Boots: The Last Wish
# 9          Miraculous: Tales of Ladybug & Cat Noir
# 11                                        Coraline
# ...                                            ...
# 45679                                Marmalade Boy
# 45688                     JoJo's Bizarre Adventure
# 45703               Demon Slayer: Kimetsu no Yaiba
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
#
#                               Genre  User Rating Number of Votes  Runtime  \
# 1      Animation, Action, Adventure     7.398438          28,895   99 min
# 2      Animation, Adventure, Comedy     7.101562         189,108   92 min
# 7      Animation, Adventure, Comedy     7.800781         153,495  102 min
# ...

# %%
#Teenage Mutant Ninja Turtles: Mutant Mayhem,The Super Mario Bros. Movie,Puss in Boots: The Last Wish etc have the rating between 7.0 and 7.9

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45717 entries, 0 to 45716
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            45717 non-null  object
#  1   Genre            45717 non-null  object
#  2   User Rating      45717 non-null  float16
#  3   Number of Votes  45717 non-null  object
#  4   Runtime          45717 non-null  object
#  5   Year             45717 non-null  object
#  6   Summary          45717 non-null  object
#  7   Stars            45717 non-null  object
#  8   Certificate      45717 non-null  object
#  9   Metascore        45716 non-null  object
#  10  Gross            45717 non-null  object
#  11  Episode          45717 non-null  object
#  12  Episode Title    44877 non-null  object
#  13  runtime          45717 non-null  object
# dtypes: float16(1), object(13)
# memory usage: 4.6+ MB

# %%
# Which anime has the highest and lowest runtime?
b['runtime']=b["Runtime"].apply(lambda x:x.split()[0])
b
# Out:
#                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 3                                  Attack on Titan
# 4                                   Jujutsu Kaisen
# ...                                            ...
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
# 45714                                    One Piece
# 45715                                Marmalade Boy
# 45716                              Cinderella Nine
#
#                               Genre  User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure     8.898438         187,689  24 min
# 1      Animation, Action, Adventure     7.398438          28,895  99 min
# 2      Animation, Adventure, Comedy     7.101562         189,108  92 min
# ...

# %%
b
# Out:
#                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 3                                  Attack on Titan
# 4                                   Jujutsu Kaisen
# ...                                            ...
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
# 45714                                    One Piece
# 45715                                Marmalade Boy
# 45716                              Cinderella Nine
#
#                               Genre  User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure     8.898438         187,689  24 min
# 1      Animation, Action, Adventure     7.398438          28,895  99 min
# 2      Animation, Adventure, Comedy     7.101562         189,108  92 min
# ...

# %%
b['runtime'].max()
# Out:
# 'Runtime'

# %%
b.replace({'runtime':{"Runtime":0,'1,250':1250,'1,271':1271,'1,080':1080}},inplace=True)

# %%
c=b.astype({"runtime":np.float16})
c
# Out:
#                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 3                                  Attack on Titan
# 4                                   Jujutsu Kaisen
# ...                                            ...
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
# 45714                                    One Piece
# 45715                                Marmalade Boy
# 45716                              Cinderella Nine
#
#                               Genre  User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure     8.898438         187,689  24 min
# 1      Animation, Action, Adventure     7.398438          28,895  99 min
# 2      Animation, Adventure, Comedy     7.101562         189,108  92 min
# ...

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45717 entries, 0 to 45716
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            45717 non-null  object
#  1   Genre            45717 non-null  object
#  2   User Rating      45717 non-null  float16
#  3   Number of Votes  45717 non-null  object
#  4   Runtime          45717 non-null  object
#  5   Year             45717 non-null  object
#  6   Summary          45717 non-null  object
#  7   Stars            45717 non-null  object
#  8   Certificate      45717 non-null  object
#  9   Metascore        45716 non-null  object
#  10  Gross            45717 non-null  object
#  11  Episode          45717 non-null  object
#  12  Episode Title    44877 non-null  object
#  13  runtime          45717 non-null  float16
# dtypes: float16(2), object(12)
# memory usage: 4.4+ MB

# %%
c.head(841)
# Out:
#                                            Title  \
# 0                                      One Piece
# 1    Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                    The Super Mario Bros. Movie
# 3                                Attack on Titan
# 4                                 Jujutsu Kaisen
# ..                                           ...
# 836                             Plastic Memories
# 837                             Strike the Blood
# 838                                  Devils Line
# 839                                Magnetic Rose
# 840                                        Title
#
#                             Genre  User Rating  Number of Votes  Runtime  \
# 0    Animation, Action, Adventure     8.898438          187,689   24 min
# 1    Animation, Action, Adventure     7.398438           28,895   99 min
# 2    Animation, Adventure, Comedy     7.101562          189,108   92 min
# 3    Animation, Action, Adventure     9.101562          434,457   24 min
# ...

# %%
c["runtime"].max()
# Out:
# 1271.0

# %%
c.loc[c["runtime"]==1271.0]
# Out:
#                            Title                         Genre  User Rating  \
# 2798  The Wonderful Wizard of Oz  Animation, Adventure, Family     7.699219
#
#      Number of Votes    Runtime         Year  \
# 2798             331  1,271 min  (1986–1987)
#
#                                                 Summary  \
# 2798  When Dorothy and her little dog Toto are swept...
#
#                                                   Stars Certificate  \
# 2798  Morgan Hallett,Sumi Shimamoto,Mark Denis,Yoshi...        TV-Y
#
#        Metascore Gross Episode  Episode Title  runtime
# 2798  33           331       0  Episode Title   1271.0

# %%
#The Wonderful Wizard of Oz have the highest runtime

# %%
c.drop(840,inplace=True)

# %%
c['runtime'].min()
# Out:
# 1.0

# %%
c.loc[c["runtime"]==1.0]
# Out:
#                             Title                     Genre  User Rating  \
# 2809                   Ani*Kuri15  Animation, Short, Comedy     6.601562
# 2810          Inazuma Eleven Ares          Animation, Sport     6.398438
# 3588                Henkei Shoujo          Animation, Short     5.199219
# 3708   Gloomy the Naughty Grizzly         Animation, Comedy     4.800781
# 4548                      Usavich                 Animation     7.500000
# ...                           ...                       ...          ...
# 23773  Gloomy the Naughty Grizzly         Animation, Comedy     4.199219
# 23774  Gloomy the Naughty Grizzly         Animation, Comedy     4.398438
# 23775  Gloomy the Naughty Grizzly         Animation, Comedy     4.199219
# 23776             Dog of Flanders  Animation, Drama, Family     4.199219
# 33433                  Ani*Kuri15  Animation, Short, Comedy     7.101562
#
#       Number of Votes Runtime         Year  \
# 2809              665   1 min  (2007–2008)
# ...

# %%
#Ani*Kuri15,Inazuma Eleven AresHenkei Shoujo have the lowest run time

# %%
f=g['runtime'].mean()
# Out:
# dtype('float16')

# %%
c
# Out:
#                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 3                                  Attack on Titan
# 4                                   Jujutsu Kaisen
# ...                                            ...
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
# 45714                                    One Piece
# 45715                                Marmalade Boy
# 45716                              Cinderella Nine
#
#                               Genre  User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure     8.898438         187,689  24 min
# 1      Animation, Action, Adventure     7.398438          28,895  99 min
# 2      Animation, Adventure, Comedy     7.101562         189,108  92 min
# ...

# %%
# What is the runtime difference between one Piece and the super mario bros movie?
a=c.loc[c["Title"]=="One Piece"]
g=a["runtime"].mean()
g
# Out:
# 25.5

# %%
e=c.loc[c["Title"]=="The Super Mario Bros. Movie"]
h=e["runtime"].mean()
h
# Out:
# 92.0

# %%
g-h
# Out:
# -66.5

# %%
#the runtime difference between one Piece and the super mario bros movie is 66.5

# %%
#List all the anime that were released in the year 2023.
c.loc[c["Year"]=="(2023)"]
# Out:
#                                              Title  \
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 13                           The Boy and the Heron
# 21                    Ruby Gillman, Teenage Kraken
# 42                     Resident Evil: Death Island
# ...                                            ...
# 7965                                 Yomawari Neko
# 8558          Girls und Panzer das Finale: Part IV
# 8605                        Jinzô Mahô Shôjo Kaini
# 8840                             The Dog & The Boy
# 10314                           The Floating World
#
#                               Genre  User Rating Number of Votes  Runtime  \
# 1      Animation, Action, Adventure     7.398438          28,895   99 min
# 2      Animation, Adventure, Comedy     7.101562         189,108   92 min
# 13      Animation, Adventure, Drama     7.601562             829  124 min
# ...

# %%
#Teenage Mutant Ninja Turtles: Mutant Mayhem,The Super Mario Bros. Movie,The Boy and the Heron etc are the animes releases in 2023

# %%
#What is the average user rating of the anime which belong to the action genre?
a=c["Genre"].str.contains("Action")
c.loc[a]["User Rating"].mean()
# Out:
# inf

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45716 entries, 0 to 45716
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            45716 non-null  object
#  1   Genre            45716 non-null  object
#  2   User Rating      45716 non-null  float16
#  3   Number of Votes  45716 non-null  object
#  4   Runtime          45716 non-null  object
#  5   Year             45716 non-null  object
#  6   Summary          45716 non-null  object
#  7   Stars            45716 non-null  object
#  8   Certificate      45716 non-null  object
#  9   Metascore        45715 non-null  object
#  10  Gross            45716 non-null  object
#  11  Episode          45716 non-null  object
#  12  Episode Title    44876 non-null  object
#  13  runtime          45716 non-null  float16
# dtypes: float16(2), object(12)
# memory usage: 4.7+ MB

# %%
# Which anime has the lowest gross price?
e=c.astype({'Gross':"float16"})
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45716 entries, 0 to 45716
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            45716 non-null  object
#  1   Genre            45716 non-null  object
#  2   User Rating      45716 non-null  float16
#  3   Number of Votes  45716 non-null  object
#  4   Runtime          45716 non-null  object
#  5   Year             45716 non-null  object
#  6   Summary          45716 non-null  object
#  7   Stars            45716 non-null  object
#  8   Certificate      45716 non-null  object
#  9   Metascore        45715 non-null  object
#  10  Gross            45716 non-null  float16
#  11  Episode          45716 non-null  object
#  12  Episode Title    44876 non-null  object
#  13  runtime          45716 non-null  float16
# dtypes: float16(3), object(11)
# memory usage: 4.4+ MB

# %%
e["Gross"].min()
# Out:
# 5.0

# %%
e["Gross"].max()
# Out:
# inf

# %%
e.loc[e["Gross"]=='inf']
# Out:
#                                                    Title  \
# 3233                                          Show Time!
# 5620                                   The Peasant Noble
# 5714   Meitantei Conan Magic File 4: Osaka okonomiyak...
# 6142   Fist of the North Star Legennd of Heroes - Spe...
# 6143                                         Cartoon-Box
# ...                                                  ...
# 45605                                    Girl Beats Boys
# 45606                                    Girl Beats Boys
# 45607                                    Girl Beats Boys
# 45608                                    Girl Beats Boys
# 45609                                    Girl Beats Boys
#
#                           Genre  User Rating Number of Votes Runtime  \
# 3233           Animation, Drama     9.796875               5  63 min
# 5620          Animation, Comedy     5.398438               5  24 min
# 5714           Animation, Short     6.800781               5  26 min
# ...

# %%
#Show Time!,The Peasant Nobl,Fist of the North Star Legennd of Heroes - Spe etc have the lowest gross price

# %%
#How many anime have the PG certification?
len(c.loc[c["Certificate"]=="PG"])
# Out:
# 626

# %%
#626 animes have the PG certification

# %%
#What is the average number of votes in your dataset?
c["Number of Votes"].str.replace(",","")
c.replace({"Number of Votes":{'Number of Votes':0}},inplace=True)
c["Number of Votes"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13900\1143058536.py in <module>
#       2 c["Number of Votes"].str.replace(",","")
#       3 c.replace({"Number of Votes":{'Number of Votes':0}},inplace=True)
# ----> 4 c["Number of Votes"].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11122             **kwargs,
#   11123         ):
# > 11124             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11125
#   11126         setattr(cls, "mean", mean)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10692         **kwargs,
#   10693     ) -> Series | float:
# > 10694         return self._stat_function(
# ...

# %%
.replace({"Number of Votes":{"187,689":187689}},inplace=True)
c.replace({"Number of Votes":{"28,895":28895}},inplace=True)
c.replace({"Number of Votes":{"189,108":189108}},inplace=True)
g=c.astype({"Number of Votes":"float16"})

c["Number of Votes"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13900\3181326055.py in <module>
# ----> 1 c["Number of Votes"].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11122             **kwargs,
#   11123         ):
# > 11124             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11125
#   11126         setattr(cls, "mean", mean)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10692         **kwargs,
#   10693     ) -> Series | float:
# > 10694         return self._stat_function(
#   10695             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10696         )
#
# ...
